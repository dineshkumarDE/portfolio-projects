# %%
# %sql
drop table processed.orders;
drop table raw.orders;
drop table processed.customers;
drop table raw.customers;
drop table processed.products;
drop table raw.products;

# %%
# %sql
select *from processed.orders

# %%
# %sql
select max(row_id) from processed.orders

# %%
# %sql
SHOW PARTITIONS processed.customers

# %%
# %sql
SELECT * FROM  PROCESSED.CUSTOMERS WHERE CUSTOMER_ID='PW-19240'

# %%
# %sql
select * from processed.customers

# %%
# %sql
SELECT *
FROM processed.customers
WHERE size(dq_issues) > 0;

# %%
# %sql
SHOW PARTITIONS processed.products

# %%
# %sql
select * from processed.products where product_id='OFF-BI-19992824'

# %%
# %sql
select distinct customer_id,category,sub_category,date_trunc('YEAR', order_date) from processed.ecomm_combined_data_view_permanent
