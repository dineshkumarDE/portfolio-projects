# %%
# %sql
SHOW PARTITIONS raw.products

# %%
# %sql
select * from processed.products where size(dq_issues) > 0

# %%
# %sql
select * from processed.products where product_id='OFF-BI-10002026'

# %%
# %sql
select product_id,price_per_product from raw.products
-- where product_id in (select product_id from processed.products where size(dq_issues) > 0) 
group by product_id,price_per_product having count(*) >1 order by product_id,price_per_product
